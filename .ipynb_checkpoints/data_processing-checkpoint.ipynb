# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

lidar = pd.read_csv('../data/big_teach_data_fast_smooth2/lidar.txt', sep=' ', header=None)
actions = pd.read_csv('../data/big_teach_data_fast_smooth2/actions.txt', sep=' ', header=None)
actions.columns= ['steering_angle', 'velocity']
print("actions ", actions.shape)
print("Lidar ",lidar.shape)
# Out:
# actions  (1206, 2)
# Lidar  (1206, 1081)

# %%
def plot_vel():
    #fig, ax = plt.subplots(figsize=(16,10))
    sns.lineplot(data=actions['velocity'])

# %%
plot_vel()

# %%
negative_vel = actions.loc[actions['velocity'] <= 0.0]
actions = actions.drop(negative_vel.index)
lidar = lidar.drop(negative_vel.index)
print("actions ", actions.shape)
print("Lidar ",lidar.shape)
plot_vel()
# Out:
# actions  (1206, 2)
# Lidar  (1206, 1081)

# %%
def write_output_to_csv():
    output = lidar.copy()
    output['velocity'] = actions['velocity'].copy()
    output['steering_angle'] = actions['steering_angle'].copy()
    output.to_csv(r'../data/Dataset_refined/big_teach_data_fast_smooth2.csv', index=False, header=True)

# %%
write_output_to_csv()

# %%
#Combine all bags
dataset = pd.read_csv('../data/Dataset_refined/big_teach_data.csv', sep=',')
dataset = dataset.append(pd.read_csv('../data/Dataset_refined/big_teach_data_fast.csv', sep=','))
dataset = dataset.append(pd.read_csv('../data/Dataset_refined/big_teach_data_fast_smooth1.csv', sep=','))
dataset = dataset.append(pd.read_csv('../data/Dataset_refined/big_teach_data_fast_smooth2.csv', sep=','))

# %%
dataset.to_csv(r'../data/Dataset_refined/complete.csv', index=False, header=True)

# %%
complete = pd.read_csv('../data/Dataset_refined/big_teach_complete.csv', sep=',')
# Out:
# (10897,)

# %%
complete['steering_angle'].shape
# Out:
# (10897,)

# %%
#clip impossible turns (wrong with follow the wall...)
for i in range(len(complete)):
    if complete['steering_angle'][i] > 0.4189:
        complete['steering_angle'][i] = 0.4189
    elif complete['steering_angle'][i] < -0.4189:
        complete['steering_angle'][i] = -0.4189

# %%
complete.to_csv(r'../data/Dataset_refined/complete.csv', index=False, header=True)
