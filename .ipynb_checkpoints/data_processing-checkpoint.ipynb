# %% [markdown]
# # Data Processing
#
# ### Read CSV

# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

lidar = pd.read_csv('../data/f5_location/nobox_fg/lidar.txt', sep=' ', header=None)
actions = pd.read_csv('../data/f5_location/nobox_fg/actions.txt', sep=' ', header=None)
actions.columns= ['steering_angle', 'velocity']
print("actions ", actions.shape)
print("Lidar ",lidar.shape)

sns.lineplot(data=actions['steering_angle'])
# Out:
# actions  (879, 2)
# Lidar  (879, 1081)

# %% [markdown]
# ### Remove data when vehicle is in reverse and clip steering angle

# %%
negative_vel = actions.loc[actions['velocity'] <= 0.0]
actions = actions.drop(negative_vel.index)
lidar = lidar.drop(negative_vel.index)

output = pd.DataFrame(lidar)
output['velocity'] = actions['velocity'].copy()
output['steering_angle'] = actions['steering_angle'].copy()

for i in range(len(output)):
    if output['steering_angle'][i] > 0.4189:
        output['steering_angle'][i] = 0.4189
    elif output['steering_angle'][i] < -0.4189:
        output['steering_angle'][i] = -0.4189
        
sns.lineplot(data=output['steering_angle'])

# %% [markdown]
# ### Write to CSV

# %%
output.to_csv(r'../data/Dataset_refined/f5_shelf_fw.csv', index=False, header=True)

# %% [markdown]
# # Combine All Bags
# #### choose all files in dataset_refined folder and combine them to one file.

# %%
li = []

for file in glob.glob("../data/Dataset_refined/*.csv"):
    df = pd.read_csv(file, sep=',')
    print(file, ": ",df.shape)
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True)

frame.to_csv(r'../data/Dataset_refined/complete.csv', index=False, header=True)
print("Total dataset: ", frame.shape)
# Out:
# Shape:  (1407, 1083)
# Shape:  (879, 1083)
# Shape:  (5506, 1083)
# Shape:  (1048, 1083)
# Shape:  (1431, 1083)
# Shape:  (1275, 1083)
# Shape:  (755, 1083)
# Shape:  (1815, 1083)
# Shape:  (1206, 1083)
# Shape:  (651, 1083)
# Shape:  (2370, 1083)
# Total dataset:  (18343, 1083)

# %% [markdown]
# ##### Fix

# %%
complete = pd.read_csv('../data/Dataset_refined/complete.csv', sep=',')
for i in range(len(complete)):
    if complete['steering_angle'][i] > 0.4189:
        complete['steering_angle'][i] = 0.4189
    elif complete['steering_angle'][i] < -0.4189:
        complete['steering_angle'][i] = -0.4189
complete.to_csv(r'../data/Dataset_refined/complete.csv', index=False, header=True)
